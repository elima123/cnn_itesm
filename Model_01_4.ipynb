# %% [markdown]
# # CNN propia (baseline)

# %% [markdown]
# Brain Tumor Probability (Binary Classification)
# - Yes: tumor presente
# - No: tumor ausente

# %%
# pip install scikit-learn
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from pathlib import Path

# %% [markdown]
# ## Hyperparameters (Model Configuration)
#
# | Parameter | Value / Configuration | Rationale / Reference |
# | --- | --- | --- |
# | **Input Dimensions** | 256 | 256 x 256 pixels square resolution for spatial consistency. |
# | **Batch Size** | 8 | Set in accordance with Angelina et al. (2026, p. 9) for memory constraints. |
# | **Epochs** | 100 | Sufficient horizon to ensure convergence. |
# | **Learning Rate** | 0.0001 (Static) | Set in accordance with He et al. (2015, p. 4). |
# | **Dropout Rate** | 0.5 | Applied for regularization to mitigate overfitting (Hinton et al., 2012, p. 2). |
# | **Activation Function** | Sigmoid | Employed in the final layer for single-class probability mapping. |
# | **Loss Function** | Binary Cross-Entropy | Selected to complement the single-neuron sigmoid output. |
# | **Optimizer** | Adam | Back propagation optimization. |
# | **Data Augmentation** | Rotation, translation, zoom, and contrast | Applied only to training batches to reduce overfitting in the small dataset. |
#
# - He, K., Zhang, X., Ren, S., y Sun, J. (2015). Deep residual learning for image recognition. arXiv. https://doi.org/10.48550/arXiv.1512.03385
# - Hinton, G. E., Srivastava, N., Krizhevsky, A., Sutskever, I., y Salakhutdinov, R. R. (2012). Improving neural networks by preventing co-adaptation of feature detectors. arXiv. https://doi.org/10.48550/arXiv.1207.0580
# - Angelina, C. L., Xiao, F.-R., Vyas, S., Yang, P.-C., Chang, H.-T., & Luo, Y. (2026). Mod-SE(2): A geometric deep learning framework for brain tumor classification and segmentation in MRI images. Journal of Biomedical Science, 33, Article 11. https://doi.org/10.1186/s12929-025-01213-y

# %%
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 100
LEARNING_RATE = 0.0001
DROPOUT = 0.5
LOSS_METHOD = "binary_crossentropy"
ACTIVATION = "sigmoid"
LABEL_MODE = "binary"
PATIENCE = 15
SEED = 42

THRESHOLD = 0.5

TRAIN_DIR = "data/dataset_ready/train"
VAL_DIR = "data/dataset_ready/val"
TEST_DIR = "data/dataset_ready/test"

MODEL_TAG = "cnn_propia_04"

# %% [markdown]
# ## Dataset Structure
# ```text
# data/dataset_ready/
# +-- train/
# |   +-- no/
# |   +-- yes/
# +-- val/
# |   +-- no/
# |   +-- yes/
# +-- test/
#     +-- no/
#     +-- yes/
# ```
#
# En TensorFlow/Keras, la asignacion de etiquetas para conjuntos de datos estructurados en carpetas locales no requiere un etiquetado manual en codigo. `image_dataset_from_directory()` infiere las clases por el nombre de las carpetas y las ordena alfabeticamente: `no -> 0`, `yes -> 1`.
#
# El conjunto de **validation** se usa correctamente cuando se pasa como `validation_data=val_ds` en `model.fit()`: sirve para monitorear el entrenamiento, seleccionar el mejor checkpoint y activar early stopping. No debe recibir data augmentation ni debe usarse para reportar el resultado final. El conjunto de **test** se mantiene separado hasta el final para medir el desempeno del modelo ya entrenado.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    shuffle=False
)

classes = train_ds.class_names # Binary: ['no', 'yes']
num_classes = len(classes)
print(classes)
# Out:
# Found 151 files belonging to 2 classes.
# Found 51 files belonging to 2 classes.
# ['no', 'yes']

# %% [markdown]
# ## Data Augmentation
#
# Se agrega data augmentation para generar variaciones realistas de las imagenes de entrenamiento sin crear archivos nuevos en disco. En cada epoca, Keras aplica pequenas rotaciones, traslaciones, zoom y cambios de contraste a los batches de `train_ds`.
#
# Esto busca que el modelo no memorice tan facil el dataset pequeno y aprenda patrones mas robustos. La validacion y el test se dejan sin augmentation para medir el desempeno sobre imagenes reales, no transformadas artificialmente.
#
# For the classification head, the two 4096-unit dense layers were removed, as the task involved only two output classes (N=253), making such a high-capacity head unnecessarily complex.
# | Block       | Architecture                                |
# |-------------|---------------------------------------------|
# | **VGG19 Layer 1** | Conv(64) → Conv(64) → MaxPool               |
# | **VGG19 Layer 2** | Conv(128) → Conv(128) → MaxPool             |
# | **VGG19 Layer 3**| Conv(256) → Conv(256) → Conv(256) → MaxPool |
# | **VGG19 Layer 4** | Conv(512) → Conv(512) → Conv(512) → MaxPool |
# | **VGG19 Layer 5** | Conv(512) → Conv(512) → Conv(512) → MaxPool |
# | **Head (manual)** | Flatten → Dense(1000) → Softmax |
# - He, K., Zhang, X., Ren, S., y Sun, J. (2015). Deep residual learning for image recognition. arXiv. https://doi.org/10.48550/arXiv.1512.03385, page 4

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout, MaxPooling2D, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.layers import RandomRotation, RandomTranslation, RandomZoom, RandomContrast

# Data augmentation dentro del modelo: se activa en training y se desactiva en validation/test.
data_augmentation = Sequential(
    [
        RandomRotation(0.05, fill_mode="nearest"),
        RandomTranslation(0.05, 0.05, fill_mode="nearest"),
        RandomZoom(0.10, fill_mode="nearest"),
        RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Modelo inspirado de VGG19 https://doi.org/10.48550/arXiv.1512.03385
model = Sequential()
model.add(Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(data_augmentation)

# Block 1
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Head
model.add(GlobalAveragePooling2D())
model.add(Dropout(DROPOUT))

# Output
model.add(Dense(1, activation=ACTIVATION)) # Binary = 1
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,673 (112.00 KB)
#  Trainable params: 28,673 (112.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE
    ),
    loss=LOSS_METHOD,
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.F1Score(name="f1score", threshold=THRESHOLD)
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Train

# %%
# ! Improvement
# 12 Minutes
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        f"checkpoints/{MODEL_TAG}/{MODEL_TAG}.keras",
        save_best_only=True,
        monitor="val_f1score" # val_ prefijo automático de Keras, f1score de validation no de train
    ),
    tf.keras.callbacks.EarlyStopping(
        patience=PATIENCE,
        restore_best_weights=True
    )
]

history = model.fit(
    train_ds,
    validation_data=val_ds, 
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 443ms/step - accuracy: 0.5497 - auc: 0.5109 - f1score: 0.6304 - loss: 2.1805 - precision: 0.6374 - recall: 0.6237 - val_accuracy: 0.6078 - val_auc: 0.5371 - val_f1score: 0.7561 - val_loss: 1.3062 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.5099 - auc: 0.4840 - f1score: 0.5698 - loss: 1.6957 - precision: 0.6203 - recall: 0.5269 - val_accuracy: 0.6078 - val_auc: 0.5903 - val_f1score: 0.7561 - val_loss: 0.7449 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.5695 - auc: 0.5349 - f1score: 0.6766 - loss: 1.0856 - precision: 0.6296 - recall: 0.7312 - val_accuracy: 0.6078 - val_auc: 0.7508 - val_f1score: 0.7561 - val_loss: 0.6471 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.5099 - auc: 0.5000 - f1score: 0.6105 - loss: 0.8179 - precision: 0.5979 - recall: 0.6237 - val_accuracy: 0.6078 - val_auc: 0.6952 - val_f1score: 0.7561 - val_loss: 0.6471 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.5894 - auc: 0.6008 - f1score: 0.6900 - loss: 0.6934 - precision: 0.6449 - recall: 0.7419 - val_accuracy: 0.6078 - val_auc: 0.6927 - val_f1score: 0.7561 - val_loss: 0.6493 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.5033 - auc: 0.4304 - f1score: 0.6114 - loss: 0.7808 - precision: 0.5900 - recall: 0.6344 - val_accuracy: 0.6078 - val_auc: 0.5863 - val_f1score: 0.7561 - val_loss: 0.6590 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 350ms/step - accuracy: 0.5033 - auc: 0.5033 - f1score: 0.6512 - loss: 0.7070 - precision: 0.5738 - recall: 0.7527 - val_accuracy: 0.6078 - val_auc: 0.5306 - val_f1score: 0.7561 - val_loss: 0.6752 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.5298 - auc: 0.4469 - f1score: 0.6635 - loss: 0.7289 - precision: 0.5932 - recall: 0.7527 - val_accuracy: 0.6078 - val_auc: 0.6210 - val_f1score: 0.7561 - val_loss: 0.6563 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.5894 - auc: 0.5812 - f1score: 0.6900 - loss: 0.6656 - precision: 0.6449 - recall: 0.7419 - val_accuracy: 0.6078 - val_auc: 0.5863 - val_f1score: 0.7561 - val_loss: 0.6614 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6225 - auc: 0.5667 - f1score: 0.7467 - loss: 0.6598 - precision: 0.6364 - recall: 0.9032 - val_accuracy: 0.6078 - val_auc: 0.6065 - val_f1score: 0.7561 - val_loss: 0.6569 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 353ms/step - accuracy: 0.5894 - auc: 0.4444 - f1score: 0.7207 - loss: 0.7147 - precision: 0.6202 - recall: 0.8602 - val_accuracy: 0.6078 - val_auc: 0.6008 - val_f1score: 0.7561 - val_loss: 0.6566 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 344ms/step - accuracy: 0.5828 - auc: 0.5286 - f1score: 0.6957 - loss: 0.6725 - precision: 0.6316 - recall: 0.7742 - val_accuracy: 0.6078 - val_auc: 0.6355 - val_f1score: 0.7561 - val_loss: 0.6541 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s
100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.6093 - auc: 0.5939 - f1score: 0.7378 - loss: 0.6627 - precision: 0.6288 - recall: 0.8925 - val_accuracy: 0.6275 - val_auc: 0.7500 - val_f1score: 0.7654 - val_loss: 0.6036 - val_precision: 0.6200 - val_recall: 1.0000
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.5960 - auc: 0.5873 - f1score: 0.7240 - loss: 0.6466 - precision: 0.6250 - recall: 0.8602 - val_accuracy: 0.6275 - val_auc: 0.7532 - val_f1score: 0.7246 - val_loss: 0.6018 - val_precision: 0.6579 - val_recall: 0.8065
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.6225 - auc: 0.6594 - f1score: 0.7511 - loss: 0.6190 - precision: 0.6324 - recall: 0.9247 - val_accuracy: 0.6275 - val_auc: 0.7508 - val_f1score: 0.7532 - val_loss: 0.6017 - val_precision: 0.6304 - val_recall: 0.9355
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.5960 - auc: 0.6574 - f1score: 0.7265 - loss: 0.6319 - precision: 0.6231 - recall: 0.8710 - val_accuracy: 0.6078 - val_auc: 0.7540 - val_f1score: 0.7222 - val_loss: 0.6004 - val_precision: 0.6341 - val_recall: 0.8387
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.6093 - auc: 0.6832 - f1score: 0.7281 - loss: 0.6136 - precision: 0.6371 - recall: 0.8495 - val_accuracy: 0.6471 - val_auc: 0.7395 - val_f1score: 0.7750 - val_loss: 0.6003 - val_precision: 0.6327 - val_recall: 1.0000
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 353ms/step - accuracy: 0.6225 - auc: 0.6303 - f1score: 0.7574 - loss: 0.6448 - precision: 0.6268 - recall: 0.9570 - val_accuracy: 0.6471 - val_auc: 0.7411 - val_f1score: 0.7692 - val_loss: 0.5992 - val_precision: 0.6383 - val_recall: 0.9677
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6490 - auc: 0.6260 - f1score: 0.7644 - loss: 0.6351 - precision: 0.6515 - recall: 0.9247 - val_accuracy: 0.6667 - val_auc: 0.7613 - val_f1score: 0.7385 - val_loss: 0.5975 - val_precision: 0.7059 - val_recall: 0.7742
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.5960 - auc: 0.5908 - f1score: 0.7215 - loss: 0.6460 - precision: 0.6270 - recall: 0.8495 - val_accuracy: 0.6078 - val_auc: 0.7500 - val_f1score: 0.7297 - val_loss: 0.5973 - val_precision: 0.6279 - val_recall: 0.8710
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.6093 - auc: 0.6267 - f1score: 0.7354 - loss: 0.6385 - precision: 0.6308 - recall: 0.8817 - val_accuracy: 0.6275 - val_auc: 0.7581 - val_f1score: 0.7246 - val_loss: 0.5980 - val_precision: 0.6579 - val_recall: 0.8065
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.6159 - auc: 0.6201 - f1score: 0.7387 - loss: 0.6311 - precision: 0.6357 - recall: 0.8817 - val_accuracy: 0.6667 - val_auc: 0.7677 - val_f1score: 0.7463 - val_loss: 0.5952 - val_precision: 0.6944 - val_recall: 0.8065
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.6490 - auc: 0.6506 - f1score: 0.7310 - loss: 0.6304 - precision: 0.6923 - recall: 0.7742 - val_accuracy: 0.6667 - val_auc: 0.7605 - val_f1score: 0.7536 - val_loss: 0.5940 - val_precision: 0.6842 - val_recall: 0.8387
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 387ms/step - accuracy: 0.6026 - auc: 0.6051 - f1score: 0.7414 - loss: 0.6479 - precision: 0.6187 - recall: 0.9247 - val_accuracy: 0.6078 - val_auc: 0.7468 - val_f1score: 0.7222 - val_loss: 0.5983 - val_precision: 0.6341 - val_recall: 0.8387
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 400ms/step - accuracy: 0.6291 - auc: 0.6351 - f1score: 0.7383 - loss: 0.6278 - precision: 0.6529 - recall: 0.8495 - val_accuracy: 0.5882 - val_auc: 0.7452 - val_f1score: 0.7123 - val_loss: 0.5981 - val_precision: 0.6190 - val_recall: 0.8387
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6424 - auc: 0.6868 - f1score: 0.7652 - loss: 0.6246 - precision: 0.6423 - recall: 0.9462 - val_accuracy: 0.6275 - val_auc: 0.7565 - val_f1score: 0.7246 - val_loss: 0.5947 - val_precision: 0.6579 - val_recall: 0.8065
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.6358 - auc: 0.6687 - f1score: 0.7442 - loss: 0.6177 - precision: 0.6557 - recall: 0.8602 - val_accuracy: 0.5882 - val_auc: 0.7613 - val_f1score: 0.7123 - val_loss: 0.5914 - val_precision: 0.6190 - val_recall: 0.8387
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6689 - auc: 0.7077 - f1score: 0.7706 - loss: 0.6048 - precision: 0.6720 - recall: 0.9032 - val_accuracy: 0.6471 - val_auc: 0.7524 - val_f1score: 0.7632 - val_loss: 0.5894 - val_precision: 0.6444 - val_recall: 0.9355
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.6821 - auc: 0.6783 - f1score: 0.7838 - loss: 0.6211 - precision: 0.6744 - recall: 0.9355 - val_accuracy: 0.7059 - val_auc: 0.7468 - val_f1score: 0.7170 - val_loss: 0.5978 - val_precision: 0.8636 - val_recall: 0.6129
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.6623 - auc: 0.6504 - f1score: 0.7488 - loss: 0.6239 - precision: 0.6909 - recall: 0.8172 - val_accuracy: 0.6667 - val_auc: 0.7605 - val_f1score: 0.7463 - val_loss: 0.5874 - val_precision: 0.6944 - val_recall: 0.8065
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.6225 - auc: 0.6109 - f1score: 0.7273 - loss: 0.6418 - precision: 0.6552 - recall: 0.8172 - val_accuracy: 0.7255 - val_auc: 0.7750 - val_f1score: 0.7308 - val_loss: 0.6003 - val_precision: 0.9048 - val_recall: 0.6129
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.6358 - auc: 0.6201 - f1score: 0.7368 - loss: 0.6433 - precision: 0.6638 - recall: 0.8280 - val_accuracy: 0.6471 - val_auc: 0.7395 - val_f1score: 0.7750 - val_loss: 0.6036 - val_precision: 0.6327 - val_recall: 1.0000
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 416ms/step - accuracy: 0.6490 - auc: 0.6531 - f1score: 0.7602 - loss: 0.6275 - precision: 0.6562 - recall: 0.9032 - val_accuracy: 0.6863 - val_auc: 0.7629 - val_f1score: 0.7500 - val_loss: 0.5911 - val_precision: 0.7273 - val_recall: 0.7742
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 376ms/step - accuracy: 0.6490 - auc: 0.6529 - f1score: 0.7464 - loss: 0.6269 - precision: 0.6724 - recall: 0.8387 - val_accuracy: 0.7255 - val_auc: 0.7532 - val_f1score: 0.7500 - val_loss: 0.5951 - val_precision: 0.8400 - val_recall: 0.6774
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.6026 - auc: 0.6317 - f1score: 0.7115 - loss: 0.6238 - precision: 0.6435 - recall: 0.7957 - val_accuracy: 0.6471 - val_auc: 0.7387 - val_f1score: 0.7353 - val_loss: 0.5911 - val_precision: 0.6757 - val_recall: 0.8065
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.6291 - auc: 0.6613 - f1score: 0.7607 - loss: 0.6192 - precision: 0.6312 - recall: 0.9570 - val_accuracy: 0.6078 - val_auc: 0.7427 - val_f1score: 0.7222 - val_loss: 0.5910 - val_precision: 0.6341 - val_recall: 0.8387
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.6093 - auc: 0.6679 - f1score: 0.6974 - loss: 0.6216 - precision: 0.6667 - recall: 0.7312 - val_accuracy: 0.6667 - val_auc: 0.7395 - val_f1score: 0.7213 - val_loss: 0.5917 - val_precision: 0.7333 - val_recall: 0.7097
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 403ms/step - accuracy: 0.6556 - auc: 0.7060 - f1score: 0.7658 - loss: 0.5981 - precision: 0.6589 - recall: 0.9140 - val_accuracy: 0.6471 - val_auc: 0.7411 - val_f1score: 0.7632 - val_loss: 0.5941 - val_precision: 0.6444 - val_recall: 0.9355
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.6159 - auc: 0.5857 - f1score: 0.7315 - loss: 0.6589 - precision: 0.6423 - recall: 0.8495 - val_accuracy: 0.6863 - val_auc: 0.7331 - val_f1score: 0.7037 - val_loss: 0.5999 - val_precision: 0.8261 - val_recall: 0.6129

# %% [markdown]
# ## Training Curves

# %%
reportPath = os.path.join("reports", MODEL_TAG)
Path(reportPath).mkdir(parents=True, exist_ok=True)

skipEarlyEpochs = 3 # Remueve las primeras 3 epochs (aplastamiento visual de la grafica)

# Accuracy graph
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Train","Validation"])
plt.title("Accuracy")
plt.savefig(os.path.join(reportPath, "accuracy.png"), dpi=300, bbox_inches="tight")
plt.show()

# Loss graph
plt.figure(figsize=(10,4))
plt.plot(history.history["loss"][skipEarlyEpochs:])
plt.plot(history.history["val_loss"][skipEarlyEpochs:]) 
plt.legend(["Train","Validation"])
plt.title("Loss")
plt.savefig(os.path.join(reportPath, "loss.png"), dpi=300, bbox_inches="tight")
plt.show()

# New, recall graph, esta es la estadística que marco la mejora desde el modelo anterior
plt.figure(figsize=(10,4))
plt.plot(history.history["recall"])
plt.plot(history.history["val_recall"]) 
plt.legend(["Train","Validation"])
plt.title("Recall")
plt.savefig(os.path.join(reportPath, "recall.png"), dpi=300, bbox_inches="tight")
plt.show()

# New, f1score graph
plt.figure(figsize=(10,4))
plt.plot(history.history["f1score"])
plt.plot(history.history["val_f1score"]) 
plt.legend(["Train","Validation"])
plt.title("F1-Score")
plt.savefig(os.path.join(reportPath, "f1score.png"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Already saved based on f1score performance
