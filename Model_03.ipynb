# %% [markdown]
# # google/efficientnet-b0
# https://arxiv.org/abs/1905.11946

# %% [markdown]
# Brain Tumor Probability (Binary Classification)
# - Yes: tumor presente
# - No: tumor ausente

# %%
# pip install scikit-learn
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from pathlib import Path

# %% [markdown]
# ## Hyperparameters (Model Configuration)
#
# | Parameter | Value / Configuration | Rationale / Reference |
# | --- | --- | --- |
# | **Input Dimensions** | 256 | 256 x 256 pixels square resolution for spatial consistency. |
# | **Batch Size** | 8 | Set in accordance with Angelina et al. (2026, p. 9) for memory constraints. |
# | **Epochs** | 200 | Incremeneted so it can learn longer. EarlyStopping applied. |
# | **Learning Rate** | 0.0001 (Static) | Set in accordance with He et al. (2015, p. 4). |
# | **Dropout Rate** | 0.5 | Applied for regularization to mitigate overfitting (Hinton et al., 2012, p. 2). |
# | **Activation Function** | Sigmoid | Employed in the final layer for single-class probability mapping. |
# | **Loss Function** | Binary Cross-Entropy | Selected to complement the single-neuron sigmoid output. |
# | **Optimizer** | Adam | Back propagation optimization. |
# | **Data Augmentation** | Rotation, translation, zoom, and contrast | Applied only to training batches to reduce overfitting in the small dataset. |
#
# - He, K., Zhang, X., Ren, S., y Sun, J. (2015). Deep residual learning for image recognition. arXiv. https://doi.org/10.48550/arXiv.1512.03385
# - Hinton, G. E., Srivastava, N., Krizhevsky, A., Sutskever, I., y Salakhutdinov, R. R. (2012). Improving neural networks by preventing co-adaptation of feature detectors. arXiv. https://doi.org/10.48550/arXiv.1207.0580
# - Angelina, C. L., Xiao, F.-R., Vyas, S., Yang, P.-C., Chang, H.-T., & Luo, Y. (2026). Mod-SE(2): A geometric deep learning framework for brain tumor classification and segmentation in MRI images. Journal of Biomedical Science, 33, Article 11. https://doi.org/10.1186/s12929-025-01213-y

# %%
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 200
LEARNING_RATE = 0.0001
DROPOUT = 0.5
LOSS_METHOD = "binary_crossentropy"
ACTIVATION = "sigmoid"
LABEL_MODE = "binary"
PATIENCE = 10
SEED = 42

THRESHOLD = 0.5

TRAIN_DIR = "data/dataset_ready/train"
VAL_DIR = "data/dataset_ready/val"
TEST_DIR = "data/dataset_ready/test"

MODEL_TAG = "efficientnetb0"

# %% [markdown]
# ## Dataset Structure
# ```text
# data/dataset_ready/
# +-- train/
# |   +-- no/
# |   +-- yes/
# +-- val/
# |   +-- no/
# |   +-- yes/
# +-- test/
#     +-- no/
#     +-- yes/
# ```
#
# En TensorFlow/Keras, la asignacion de etiquetas para conjuntos de datos estructurados en carpetas locales no requiere un etiquetado manual en codigo. `image_dataset_from_directory()` infiere las clases por el nombre de las carpetas y las ordena alfabeticamente: `no -> 0`, `yes -> 1`.
#
# El conjunto de **validation** se usa correctamente cuando se pasa como `validation_data=val_ds` en `model.fit()`: sirve para monitorear el entrenamiento, seleccionar el mejor checkpoint y activar early stopping. No debe recibir data augmentation ni debe usarse para reportar el resultado final. El conjunto de **test** se mantiene separado hasta el final para medir el desempeno del modelo ya entrenado.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    shuffle=False
)

classes = train_ds.class_names # Binary: ['no', 'yes']
num_classes = len(classes)
print(classes)
# Out:
# Found 151 files belonging to 2 classes.
# Found 51 files belonging to 2 classes.
# ['no', 'yes']

# %% [markdown]
# ## Data Augmentation
#
# Se agrega data augmentation para generar variaciones realistas de las imagenes de entrenamiento sin crear archivos nuevos en disco. En cada epoca, Keras aplica pequenas rotaciones, traslaciones, zoom y cambios de contraste a los batches de `train_ds`.
#
# Esto busca que el modelo no memorice tan facil el dataset pequeno y aprenda patrones mas robustos. La validacion y el test se dejan sin augmentation para medir el desempeno sobre imagenes reales, no transformadas artificialmente.
#
# For the classification head, the two 4096-unit dense layers were removed, as the task involved only two output classes (N=256), making such a high-capacity head unnecessarily complex.
# | Block       | Architecture                                |
# |-------------|---------------------------------------------|
# | **VGG16 Layer 1** | Conv(64) → Conv(64) → MaxPool               |
# | **VGG16 Layer 2** | Conv(128) → Conv(128) → MaxPool             |
# | **VGG16 Layer 3**| Conv(256) → Conv(256) → Conv(256) → MaxPool |
# | **VGG16 Layer 4** | Conv(512) → Conv(512) → Conv(512) → MaxPool |
# | **VGG16 Layer 5** | Conv(512) → Conv(512) → Conv(512) → MaxPool |
# | **Head (manual)** | Flatten → Dense(1000) → Softmax |
# - He, K., Zhang, X., Ren, S., y Sun, J. (2015). Deep residual learning for image recognition. arXiv. https://doi.org/10.48550/arXiv.1512.03385, page 4

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from tensorflow.keras.layers import RandomRotation, RandomTranslation, RandomZoom, RandomContrast

# Data augmentation dentro del modelo: se activa en training y se desactiva en validation/test.
data_augmentation = Sequential(
    [
        RandomRotation(0.05, fill_mode="nearest"),
        RandomTranslation(0.05, 0.05, fill_mode="nearest"),
        RandomZoom(0.10, fill_mode="nearest"),
        RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Modelo google/efficientnet-b0
base_model = tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False

# Modelo vacio listo para ser añadido con el backbone de efficientnet
model = Sequential()
model.add(Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(data_augmentation)
model.add(base_model)

# Head
model.add(GlobalAveragePooling2D())
model.add(Dense(128, activation="relu"))
model.add(Dropout(DROPOUT))

# Output
model.add(Dense(1, activation=ACTIVATION)) # Binary = 1
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 8, 8, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,213,668 (16.07 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %% [markdown]
# ## Compile

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE
    ),
    loss=LOSS_METHOD,
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.F1Score(name="f1score", threshold=THRESHOLD)
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Train

# %%
# 13 Minutes
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        f"checkpoints/{MODEL_TAG}/{MODEL_TAG}.keras",
        save_best_only=True,
        monitor="val_f1score" # val_ prefijo automático de Keras, f1score de validation no de train
    ),
    tf.keras.callbacks.EarlyStopping(
        patience=PATIENCE,
        restore_best_weights=True
    )
]

history = model.fit(
    train_ds,
    validation_data=val_ds, 
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 41s 880ms/step - accuracy: 0.5099 - auc: 0.5303 - f1score: 0.5889 - loss: 0.7079 - precision: 0.6092 - recall: 0.5699 - val_accuracy: 0.6078 - val_auc: 0.6032 - val_f1score: 0.7059 - val_loss: 0.6649 - val_precision: 0.6486 - val_recall: 0.7742
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 592ms/step - accuracy: 0.5430 - auc: 0.5405 - f1score: 0.6761 - loss: 0.6914 - precision: 0.6000 - recall: 0.7742 - val_accuracy: 0.6471 - val_auc: 0.7581 - val_f1score: 0.7568 - val_loss: 0.6118 - val_precision: 0.6512 - val_recall: 0.9032
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 603ms/step - accuracy: 0.6159 - auc: 0.6542 - f1score: 0.7238 - loss: 0.6409 - precision: 0.6496 - recall: 0.8172 - val_accuracy: 0.7451 - val_auc: 0.8548 - val_f1score: 0.8169 - val_loss: 0.5643 - val_precision: 0.7250 - val_recall: 0.9355
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 583ms/step - accuracy: 0.7020 - auc: 0.7595 - f1score: 0.7867 - loss: 0.5800 - precision: 0.7034 - recall: 0.8925 - val_accuracy: 0.8039 - val_auc: 0.8911 - val_f1score: 0.8485 - val_loss: 0.5340 - val_precision: 0.8000 - val_recall: 0.9032
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 586ms/step - accuracy: 0.7020 - auc: 0.7646 - f1score: 0.7716 - loss: 0.5680 - precision: 0.7308 - recall: 0.8172 - val_accuracy: 0.8627 - val_auc: 0.9234 - val_f1score: 0.8889 - val_loss: 0.4949 - val_precision: 0.8750 - val_recall: 0.9032
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 568ms/step - accuracy: 0.7483 - auc: 0.7963 - f1score: 0.8081 - loss: 0.5310 - precision: 0.7619 - recall: 0.8602 - val_accuracy: 0.8431 - val_auc: 0.9387 - val_f1score: 0.8788 - val_loss: 0.4711 - val_precision: 0.8286 - val_recall: 0.9355
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 532ms/step - accuracy: 0.7550 - auc: 0.8391 - f1score: 0.8195 - loss: 0.5024 - precision: 0.7500 - recall: 0.9032 - val_accuracy: 0.7843 - val_auc: 0.9516 - val_f1score: 0.8406 - val_loss: 0.4492 - val_precision: 0.7632 - val_recall: 0.9355
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s
200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 564ms/step - accuracy: 0.8609 - auc: 0.9194 - f1score: 0.8901 - loss: 0.3595 - precision: 0.8673 - recall: 0.9140 - val_accuracy: 0.9608 - val_auc: 0.9968 - val_f1score: 0.9667 - val_loss: 0.2310 - val_precision: 1.0000 - val_recall: 0.9355
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 528ms/step - accuracy: 0.8940 - auc: 0.9595 - f1score: 0.9149 - loss: 0.3067 - precision: 0.9053 - recall: 0.9247 - val_accuracy: 0.9608 - val_auc: 1.0000 - val_f1score: 0.9667 - val_loss: 0.2278 - val_precision: 1.0000 - val_recall: 0.9355
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 595ms/step - accuracy: 0.9007 - auc: 0.9554 - f1score: 0.9198 - loss: 0.3041 - precision: 0.9149 - recall: 0.9247 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1score: 1.0000 - val_loss: 0.2187 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 559ms/step - accuracy: 0.9139 - auc: 0.9549 - f1score: 0.9312 - loss: 0.2892 - precision: 0.9167 - recall: 0.9462 - val_accuracy: 0.9608 - val_auc: 1.0000 - val_f1score: 0.9667 - val_loss: 0.2163 - val_precision: 1.0000 - val_recall: 0.9355
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 543ms/step - accuracy: 0.8675 - auc: 0.9560 - f1score: 0.8901 - loss: 0.2903 - precision: 0.9101 - recall: 0.8710 - val_accuracy: 0.9608 - val_auc: 0.9984 - val_f1score: 0.9677 - val_loss: 0.2104 - val_precision: 0.9677 - val_recall: 0.9677
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 571ms/step - accuracy: 0.8477 - auc: 0.9334 - f1score: 0.8796 - loss: 0.3280 - precision: 0.8571 - recall: 0.9032 - val_accuracy: 0.9804 - val_auc: 0.9992 - val_f1score: 0.9836 - val_loss: 0.2058 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 559ms/step - accuracy: 0.8874 - auc: 0.9511 - f1score: 0.9101 - loss: 0.3046 - precision: 0.8958 - recall: 0.9247 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9836 - val_loss: 0.2028 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 571ms/step - accuracy: 0.9007 - auc: 0.9675 - f1score: 0.9189 - loss: 0.2692 - precision: 0.9239 - recall: 0.9140 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9836 - val_loss: 0.1991 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 543ms/step - accuracy: 0.8940 - auc: 0.9591 - f1score: 0.9149 - loss: 0.2802 - precision: 0.9053 - recall: 0.9247 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.1942 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 555ms/step - accuracy: 0.8940 - auc: 0.9657 - f1score: 0.9167 - loss: 0.2686 - precision: 0.8889 - recall: 0.9462 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.1916 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 544ms/step - accuracy: 0.9073 - auc: 0.9707 - f1score: 0.9263 - loss: 0.2627 - precision: 0.9072 - recall: 0.9462 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9836 - val_loss: 0.1897 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 538ms/step - accuracy: 0.9073 - auc: 0.9474 - f1score: 0.9255 - loss: 0.2837 - precision: 0.9158 - recall: 0.9355 - val_accuracy: 0.9608 - val_auc: 0.9984 - val_f1score: 0.9667 - val_loss: 0.1941 - val_precision: 1.0000 - val_recall: 0.9355
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 532ms/step - accuracy: 0.9073 - auc: 0.9594 - f1score: 0.9255 - loss: 0.2827 - precision: 0.9158 - recall: 0.9355 - val_accuracy: 0.9608 - val_auc: 0.9984 - val_f1score: 0.9667 - val_loss: 0.1900 - val_precision: 1.0000 - val_recall: 0.9355
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 532ms/step - accuracy: 0.9073 - auc: 0.9620 - f1score: 0.9263 - loss: 0.2692 - precision: 0.9072 - recall: 0.9462 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.1834 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 530ms/step - accuracy: 0.9073 - auc: 0.9633 - f1score: 0.9263 - loss: 0.2682 - precision: 0.9072 - recall: 0.9462 - val_accuracy: 0.9608 - val_auc: 0.9968 - val_f1score: 0.9677 - val_loss: 0.1839 - val_precision: 0.9677 - val_recall: 0.9677
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 552ms/step - accuracy: 0.9272 - auc: 0.9702 - f1score: 0.9418 - loss: 0.2564 - precision: 0.9271 - recall: 0.9570 - val_accuracy: 0.9608 - val_auc: 0.9984 - val_f1score: 0.9677 - val_loss: 0.1783 - val_precision: 0.9677 - val_recall: 0.9677
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 553ms/step - accuracy: 0.9139 - auc: 0.9617 - f1score: 0.9312 - loss: 0.2714 - precision: 0.9167 - recall: 0.9462 - val_accuracy: 0.9804 - val_auc: 0.9968 - val_f1score: 0.9841 - val_loss: 0.1772 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 533ms/step - accuracy: 0.9007 - auc: 0.9664 - f1score: 0.9206 - loss: 0.2669 - precision: 0.9062 - recall: 0.9355 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.1711 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 534ms/step - accuracy: 0.9073 - auc: 0.9840 - f1score: 0.9239 - loss: 0.2243 - precision: 0.9341 - recall: 0.9140 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9841 - val_loss: 0.1648 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 550ms/step - accuracy: 0.9205 - auc: 0.9748 - f1score: 0.9362 - loss: 0.2326 - precision: 0.9263 - recall: 0.9462 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9836 - val_loss: 0.1657 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 542ms/step - accuracy: 0.9338 - auc: 0.9668 - f1score: 0.9468 - loss: 0.2507 - precision: 0.9368 - recall: 0.9570 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9836 - val_loss: 0.1635 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 539ms/step - accuracy: 0.9073 - auc: 0.9498 - f1score: 0.9247 - loss: 0.2910 - precision: 0.9247 - recall: 0.9247 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9836 - val_loss: 0.1677 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 531ms/step - accuracy: 0.9338 - auc: 0.9856 - f1score: 0.9462 - loss: 0.2090 - precision: 0.9462 - recall: 0.9462 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.
- val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.1252 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 535ms/step - accuracy: 0.9404 - auc: 0.9785 - f1score: 0.9524 - loss: 0.2011 - precision: 0.9375 - recall: 0.9677 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9841 - val_loss: 0.1251 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 545ms/step - accuracy: 0.9272 - auc: 0.9834 - f1score: 0.9424 - loss: 0.1851 - precision: 0.9184 - recall: 0.9677 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1score: 1.0000 - val_loss: 0.1260 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 577ms/step - accuracy: 0.9205 - auc: 0.9847 - f1score: 0.9368 - loss: 0.1825 - precision: 0.9175 - recall: 0.9570 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9836 - val_loss: 0.1267 - val_precision: 1.0000 - val_recall: 0.9677
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 549ms/step - accuracy: 0.9404 - auc: 0.9913 - f1score: 0.9519 - loss: 0.1595 - precision: 0.9468 - recall: 0.9570 - val_accuracy: 0.9804 - val_auc: 1.0000 - val_f1score: 0.9841 - val_loss: 0.1250 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 554ms/step - accuracy: 0.9536 - auc: 0.9931 - f1score: 0.9626 - loss: 0.1491 - precision: 0.9574 - recall: 0.9677 - val_accuracy: 0.9804 - val_auc: 0.9984 - val_f1score: 0.9841 - val_loss: 0.1223 - val_precision: 0.9688 - val_recall: 1.0000
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 543ms/step - accuracy: 0.9536 - auc: 0.9879 - f1score: 0.9626 - loss: 0.1762 - precision: 0.9574 - recall: 0.9677 - val_accuracy: 0.9608 - val_auc: 0.9984 - val_f1score: 0.9677 - val_loss: 0.1236 - val_precision: 0.9677 - val_recall: 0.9677

# %% [markdown]
# ## Training Curves

# %%
reportPath = os.path.join("reports", MODEL_TAG)
Path(reportPath).mkdir(parents=True, exist_ok=True)

skipEarlyEpochs = 3 # Remueve las primeras 3 epochs (aplastamiento visual de la grafica)

# Accuracy graph
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Train","Validation"])
plt.title("Accuracy")
plt.savefig(os.path.join(reportPath, "accuracy.png"), dpi=300, bbox_inches="tight")
plt.show()

# Loss graph
plt.figure(figsize=(10,4))
plt.plot(history.history["loss"][skipEarlyEpochs:])
plt.plot(history.history["val_loss"][skipEarlyEpochs:]) 
plt.legend(["Train","Validation"])
plt.title("Loss")
plt.savefig(os.path.join(reportPath, "loss.png"), dpi=300, bbox_inches="tight")
plt.show()

# Recall graph
plt.figure(figsize=(10,4))
plt.plot(history.history["recall"])
plt.plot(history.history["val_recall"]) 
plt.legend(["Train","Validation"])
plt.title("Recall")
plt.savefig(os.path.join(reportPath, "recall.png"), dpi=300, bbox_inches="tight")
plt.show()

# F1 score graph
plt.figure(figsize=(10,4))
plt.plot(history.history["f1score"])
plt.plot(history.history["val_f1score"]) 
plt.legend(["Train","Validation"])
plt.title("F1-Score")
plt.savefig(os.path.join(reportPath, "f1score.png"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Save Model is already saved based on f1score performance
