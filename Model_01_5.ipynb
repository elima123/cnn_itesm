# %% [markdown]
# # CNN propia (baseline)

# %% [markdown]
# Brain Tumor Probability (Binary Classification)
# - Yes: tumor presente
# - No: tumor ausente

# %%
# pip install scikit-learn
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from pathlib import Path

# %% [markdown]
# ## Hyperparameters (Model Configuration)
#
# | Parameter | Value / Configuration | Rationale / Reference |
# | --- | --- | --- |
# | **Input Dimensions** | 256 | 256 x 256 pixels square resolution for spatial consistency. |
# | **Batch Size** | 8 | Set in accordance with Angelina et al. (2026, p. 9) for memory constraints. |
# | **Epochs** | 100 | Sufficient horizon to ensure convergence. |
# | **Learning Rate** | 0.0001 (Static) | Set in accordance with He et al. (2015, p. 4). |
# | **Dropout Rate** | 0.5 | Applied for regularization to mitigate overfitting (Hinton et al., 2012, p. 2). |
# | **Activation Function** | Sigmoid | Employed in the final layer for single-class probability mapping. |
# | **Loss Function** | Binary Cross-Entropy | Selected to complement the single-neuron sigmoid output. |
# | **Optimizer** | Adam | Back propagation optimization. |
# | **Data Augmentation** | Rotation, translation, zoom, and contrast | Applied only to training batches to reduce overfitting in the small dataset. |
#
# - He, K., Zhang, X., Ren, S., y Sun, J. (2015). Deep residual learning for image recognition. arXiv. https://doi.org/10.48550/arXiv.1512.03385
# - Hinton, G. E., Srivastava, N., Krizhevsky, A., Sutskever, I., y Salakhutdinov, R. R. (2012). Improving neural networks by preventing co-adaptation of feature detectors. arXiv. https://doi.org/10.48550/arXiv.1207.0580
# - Angelina, C. L., Xiao, F.-R., Vyas, S., Yang, P.-C., Chang, H.-T., & Luo, Y. (2026). Mod-SE(2): A geometric deep learning framework for brain tumor classification and segmentation in MRI images. Journal of Biomedical Science, 33, Article 11. https://doi.org/10.1186/s12929-025-01213-y

# %%
MODEL_TAG = "cnn_propia_05"

IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 200
LEARNING_RATE = 0.0001
DROPOUT = 0.5
LOSS_METHOD = "binary_crossentropy"
ACTIVATION = "sigmoid"
LABEL_MODE = "binary"
PATIENCE = 10
SEED = 42
THRESHOLD = 0.5

TRAIN_DIR = "data/dataset_ready/train"
VAL_DIR = "data/dataset_ready/val"
TEST_DIR = "data/dataset_ready/test"

# %% [markdown]
# ## Dataset Structure
# ```text
# data/dataset_ready/
# +-- train/
# |   +-- no/
# |   +-- yes/
# +-- val/
# |   +-- no/
# |   +-- yes/
# +-- test/
#     +-- no/
#     +-- yes/
# ```
#
# En TensorFlow/Keras, la asignacion de etiquetas para conjuntos de datos estructurados en carpetas locales no requiere un etiquetado manual en codigo. `image_dataset_from_directory()` infiere las clases por el nombre de las carpetas y las ordena alfabeticamente: `no -> 0`, `yes -> 1`.
#
# El conjunto de **validation** se usa correctamente cuando se pasa como `validation_data=val_ds` en `model.fit()`: sirve para monitorear el entrenamiento, seleccionar el mejor checkpoint y activar early stopping. No debe recibir data augmentation ni debe usarse para reportar el resultado final. El conjunto de **test** se mantiene separado hasta el final para medir el desempeno del modelo ya entrenado.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=LABEL_MODE,
    shuffle=False
)

classes = train_ds.class_names # Binary: ['no', 'yes']
num_classes = len(classes)
print(classes)
# Out:
# Found 151 files belonging to 2 classes.
# Found 51 files belonging to 2 classes.
# ['no', 'yes']

# %% [markdown]
# ## Data Augmentation
#
# Se agrega data augmentation para generar variaciones realistas de las imagenes de entrenamiento sin crear archivos nuevos en disco. En cada epoca, Keras aplica pequenas rotaciones, traslaciones, zoom y cambios de contraste a los batches de `train_ds`.
#
# Esto busca que el modelo no memorice tan facil el dataset pequeno y aprenda patrones mas robustos. La validacion y el test se dejan sin augmentation para medir el desempeno sobre imagenes reales, no transformadas artificialmente.
#
# For the classification head, the two 4096-unit dense layers were removed, as the task involved only two output classes (N=253), making such a high-capacity head unnecessarily complex.
# | Block       | Architecture                                |
# |-------------|---------------------------------------------|
# | **VGG19 Layer 1** | Conv(64) → Conv(64) → MaxPool               |
# | **VGG19 Layer 2** | Conv(128) → Conv(128) → MaxPool             |
# | **VGG19 Layer 3**| Conv(256) → Conv(256) → Conv(256) → MaxPool |
# | **VGG19 Layer 4** | Conv(512) → Conv(512) → Conv(512) → MaxPool |
# | **VGG19 Layer 5** | Conv(512) → Conv(512) → Conv(512) → MaxPool |
# | **Head (manual)** | Flatten → Dense(1000) → Softmax |
# - He, K., Zhang, X., Ren, S., y Sun, J. (2015). Deep residual learning for image recognition. arXiv. https://doi.org/10.48550/arXiv.1512.03385, page 4

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout, MaxPooling2D, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.layers import RandomRotation, RandomTranslation, RandomZoom, RandomContrast

# Data augmentation dentro del modelo: se activa en training y se desactiva en validation/test.
data_augmentation = Sequential(
    [
        RandomRotation(0.05, fill_mode="nearest"),
        RandomTranslation(0.05, 0.05, fill_mode="nearest"),
        RandomZoom(0.10, fill_mode="nearest"),
        RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Modelo inspirado de VGG19 https://doi.org/10.48550/arXiv.1512.03385
model = Sequential()
model.add(Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(data_augmentation)

# Block 1
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 3
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Head
model.add(GlobalAveragePooling2D())
model.add(Dropout(DROPOUT))

# Output
model.add(Dense(1, activation=ACTIVATION)) # Binary = 1
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_60 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_61 (Conv2D)              │ (None, 256, 256, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_62 (Conv2D)              │ (None, 256, 256, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_63 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_64 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_65 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_66 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_67 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_68 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_7      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 74,913 (292.63 KB)
#  Trainable params: 74,913 (292.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE
    ),
    loss=LOSS_METHOD,
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.F1Score(name="f1score", threshold=THRESHOLD)
    ]
)

# %% [markdown]
# ## Train

# %%
# ! Improvement
# 20 Minutes
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        f"checkpoints/{MODEL_TAG}/{MODEL_TAG}.keras",
        save_best_only=True,
        monitor="val_f1score" # val_ prefijo automático de Keras, f1score de validation no de train
    ),
    tf.keras.callbacks.EarlyStopping(
        patience=PATIENCE,
        restore_best_weights=True
    )
]

history = model.fit(
    train_ds,
    validation_data=val_ds, 
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 656ms/step - accuracy: 0.5298 - auc: 0.5128 - f1score: 0.6432 - loss: 0.7545 - precision: 0.6038 - recall: 0.6882 - val_accuracy: 0.6078 - val_auc: 0.5847 - val_f1score: 0.7561 - val_loss: 0.6857 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 14s 723ms/step - accuracy: 0.5629 - auc: 0.5273 - f1score: 0.6916 - loss: 0.6800 - precision: 0.6116 - recall: 0.7957 - val_accuracy: 0.6078 - val_auc: 0.5919 - val_f1score: 0.7561 - val_loss: 0.6631 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 642ms/step - accuracy: 0.5298 - auc: 0.4710 - f1score: 0.6816 - loss: 0.6908 - precision: 0.5846 - recall: 0.8172 - val_accuracy: 0.6078 - val_auc: 0.6234 - val_f1score: 0.7561 - val_loss: 0.6582 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 635ms/step - accuracy: 0.6026 - auc: 0.4987 - f1score: 0.7436 - loss: 0.6888 - precision: 0.6170 - recall: 0.9355 - val_accuracy: 0.6078 - val_auc: 0.5895 - val_f1score: 0.7561 - val_loss: 0.6631 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 681ms/step - accuracy: 0.5828 - auc: 0.4972 - f1score: 0.7296 - loss: 0.6793 - precision: 0.6071 - recall: 0.9140 - val_accuracy: 0.6078 - val_auc: 0.5919 - val_f1score: 0.7561 - val_loss: 0.6619 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 659ms/step - accuracy: 0.5695 - auc: 0.4502 - f1score: 0.7111 - loss: 0.6861 - precision: 0.6061 - recall: 0.8602 - val_accuracy: 0.6078 - val_auc: 0.5879 - val_f1score: 0.7561 - val_loss: 0.6699 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 634ms/step - accuracy: 0.6026 - auc: 0.5986 - f1score: 0.7479 - loss: 0.6571 - precision: 0.6138 - recall: 0.9570 - val_accuracy: 0.6078 - val_auc: 0.6081 - val_f1score: 0.7561 - val_loss: 0.6593 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 659ms/step - accuracy: 0.6026 - auc: 0.4722 - f1score: 0.7521 - loss: 0.6855 - precision: 0.6107 - recall: 0.9785 - val_accuracy: 0.6078 - val_auc: 0.6194 - val_f1score: 0.7561 - val_loss: 0.6603 - val_precision: 0.6078 - val_recall: 1.0000
# Epoch
200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 666ms/step - accuracy: 0.6291 - auc: 0.6894 - f1score: 0.7647 - loss: 0.6158 - precision: 0.6276 - recall: 0.9785 - val_accuracy: 0.6275 - val_auc: 0.7742 - val_f1score: 0.7595 - val_loss: 0.6006 - val_precision: 0.6250 - val_recall: 0.9677
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 648ms/step - accuracy: 0.6623 - auc: 0.6882 - f1score: 0.7488 - loss: 0.6242 - precision: 0.6909 - recall: 0.8172 - val_accuracy: 0.6078 - val_auc: 0.6790 - val_f1score: 0.7297 - val_loss: 0.6354 - val_precision: 0.6279 - val_recall: 0.8710
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 14s 743ms/step - accuracy: 0.6159 - auc: 0.6498 - f1score: 0.7478 - loss: 0.6238 - precision: 0.6277 - recall: 0.9247 - val_accuracy: 0.7059 - val_auc: 0.7726 - val_f1score: 0.7692 - val_loss: 0.5973 - val_precision: 0.7353 - val_recall: 0.8065
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 666ms/step - accuracy: 0.6424 - auc: 0.6402 - f1score: 0.7404 - loss: 0.6302 - precision: 0.6696 - recall: 0.8280 - val_accuracy: 0.6275 - val_auc: 0.7363 - val_f1score: 0.7595 - val_loss: 0.6120 - val_precision: 0.6250 - val_recall: 0.9677
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 637ms/step - accuracy: 0.6424 - auc: 0.6625 - f1score: 0.7589 - loss: 0.6271 - precision: 0.6489 - recall: 0.9140 - val_accuracy: 0.7451 - val_auc: 0.7734 - val_f1score: 0.7937 - val_loss: 0.5959 - val_precision: 0.7812 - val_recall: 0.8065
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.6225 - auc: 0.6851 - f1score: 0.7246 - loss: 0.6108 - precision: 0.6579 - recall: 0.8065 - val_accuracy: 0.6667 - val_auc: 0.7710 - val_f1score: 0.7536 - val_loss: 0.5906 - val_precision: 0.6842 - val_recall: 0.8387
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.6821 - auc: 0.6766 - f1score: 0.7600 - loss: 0.6143 - precision: 0.7103 - recall: 0.8172 - val_accuracy: 0.6275 - val_auc: 0.7629 - val_f1score: 0.7532 - val_loss: 0.5956 - val_precision: 0.6304 - val_recall: 0.9355
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 648ms/step - accuracy: 0.5828 - auc: 0.6475 - f1score: 0.7042 - loss: 0.6202 - precision: 0.6250 - recall: 0.8065 - val_accuracy: 0.6275 - val_auc: 0.7444 - val_f1score: 0.7654 - val_loss: 0.6280 - val_precision: 0.6200 - val_recall: 1.0000
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 651ms/step - accuracy: 0.6623 - auc: 0.6738 - f1score: 0.7671 - loss: 0.6150 - precision: 0.6667 - recall: 0.9032 - val_accuracy: 0.6863 - val_auc: 0.7581 - val_f1score: 0.7241 - val_loss: 0.5967 - val_precision: 0.7778 - val_recall: 0.6774
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 661ms/step - accuracy: 0.6291 - auc: 0.6153 - f1score: 0.7407 - loss: 0.6675 - precision: 0.6504 - recall: 0.8602 - val_accuracy: 0.7059 - val_auc: 0.7742 - val_f1score: 0.7761 - val_loss: 0.5892 - val_precision: 0.7222 - val_recall: 0.8387
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s
200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 641ms/step - accuracy: 0.6556 - auc: 0.7085 - f1score: 0.7426 - loss: 0.5863 - precision: 0.6881 - recall: 0.8065 - val_accuracy: 0.6275 - val_auc: 0.7750 - val_f1score: 0.7246 - val_loss: 0.5875 - val_precision: 0.6579 - val_recall: 0.8065
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 647ms/step - accuracy: 0.6821 - auc: 0.6848 - f1score: 0.7692 - loss: 0.6152 - precision: 0.6957 - recall: 0.8602 - val_accuracy: 0.7059 - val_auc: 0.7758 - val_f1score: 0.7170 - val_loss: 0.5960 - val_precision: 0.8636 - val_recall: 0.6129
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 647ms/step - accuracy: 0.6490 - auc: 0.6975 - f1score: 0.7337 - loss: 0.6026 - precision: 0.6887 - recall: 0.7849 - val_accuracy: 0.6667 - val_auc: 0.7677 - val_f1score: 0.7848 - val_loss: 0.6177 - val_precision: 0.6458 - val_recall: 1.0000
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 645ms/step - accuracy: 0.6358 - auc: 0.6790 - f1score: 0.7291 - loss: 0.6217 - precision: 0.6727 - recall: 0.7957 - val_accuracy: 0.6275 - val_auc: 0.7645 - val_f1score: 0.7324 - val_loss: 0.5911 - val_precision: 0.6500 - val_recall: 0.8387
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 639ms/step - accuracy: 0.6424 - auc: 0.6956 - f1score: 0.7404 - loss: 0.5957 - precision: 0.6696 - recall: 0.8280 - val_accuracy: 0.6863 - val_auc: 0.7710 - val_f1score: 0.7576 - val_loss: 0.5867 - val_precision: 0.7143 - val_recall: 0.8065
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.6821 - auc: 0.7438 - f1score: 0.7714 - loss: 0.5701 - precision: 0.6923 - recall: 0.8710 - val_accuracy: 0.7451 - val_auc: 0.7887 - val_f1score: 0.7797 - val_loss: 0.5874 - val_precision: 0.8214 - val_recall: 0.7419
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 645ms/step - accuracy: 0.6755 - auc: 0.7378 - f1score: 0.7461 - loss: 0.5810 - precision: 0.7200 - recall: 0.7742 - val_accuracy: 0.7451 - val_auc: 0.7847 - val_f1score: 0.7937 - val_loss: 0.5791 - val_precision: 0.7812 - val_recall: 0.8065
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 664ms/step - accuracy: 0.6490 - auc: 0.7028 - f1score: 0.7464 - loss: 0.5931 - precision: 0.6724 - recall: 0.8387 - val_accuracy: 0.6863 - val_auc: 0.7758 - val_f1score: 0.6923 - val_loss: 0.6054 - val_precision: 0.8571 - val_recall: 0.5806
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 673ms/step - accuracy: 0.6623 - auc: 0.6910 - f1score: 0.7560 - loss: 0.6129 - precision: 0.6810 - recall: 0.8495 - val_accuracy: 0.6667 - val_auc: 0.7798 - val_f1score: 0.6531 - val_loss: 0.6202 - val_precision: 0.8889 - val_recall: 0.5161
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 643ms/step - accuracy: 0.6887 - auc: 0.7097 - f1score: 0.7638 - loss: 0.6003 - precision: 0.7170 - recall: 0.8172 - val_accuracy: 0.6863 - val_auc: 0.7734 - val_f1score: 0.7576 - val_loss: 0.5785 - val_precision: 0.7143 - val_recall: 0.8065
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 671ms/step - accuracy: 0.7152 - auc: 0.7268 - f1score: 0.7882 - loss: 0.5897 - precision: 0.7273 - recall: 0.8602 - val_accuracy: 0.7647 - val_auc: 0.7637 - val_f1score: 0.8065 - val_loss: 0.5989 - val_precision: 0.8065 - val_recall: 0.8065
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 643ms/step - accuracy: 0.6689 - auc: 0.7287 - f1score: 0.7449 - loss: 0.5863 - precision: 0.7087 - recall: 0.7849 - val_accuracy: 0.7255 - val_auc: 0.7855 - val_f1score: 0.7500 - val_loss: 0.5945 - val_precision: 0.8400 - val_recall: 0.6774
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 638ms/step - accuracy: 0.6954 - auc: 0.7204 - f1score: 0.7723 - loss: 0.6098 - precision: 0.7156 - recall: 0.8387 - val_accuracy: 0.6667 - val_auc: 0.7669 - val_f1score: 0.6792 - val_loss: 0.6088 - val_precision: 0.8182 - val_recall: 0.5806
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 643ms/step - accuracy: 0.7086 - auc: 0.7377 - f1score: 0.7822 - loss: 0.5813 - precision: 0.7248 - recall: 0.8495 - val_accuracy: 0.6471 - val_auc: 0.7782 - val_f1score: 0.7568 - val_loss: 0.5944 - val_precision: 0.6512 - val_recall: 0.9032
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 638ms/step - accuracy: 0.6755 - auc: 0.6672 - f1score: 0.7380 - loss: 0.6451 - precision: 0.7340 - recall: 0.7419 - val_accuracy: 0.7647 - val_auc: 0.7871 - val_f1score: 0.7931 - val_loss: 0.5911 - val_precision: 0.8519 - val_recall: 0.7419
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 638ms/step - accuracy: 0.6490 - auc: 0.7147 - f1score: 0.7535 - loss: 0.5894 - precision: 0.6639 - recall: 0.8710 - val_accuracy: 0.7647 - val_auc: 0.7919 - val_f1score: 0.8000 - val_loss: 0.5756 - val_precision: 0.8276 - val_recall: 0.7742
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 643ms/step - accuracy: 0.6623 - auc: 0.7129 - f1score: 0.7463 - loss: 0.5931 - precision: 0.6944 - recall: 0.8065 - val_accuracy: 0.7059 - val_auc: 0.7782 - val_f1score: 0.7619 - val_loss: 0.5871 - val_precision: 0.7500 - val_recall: 0.7742
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 644ms/step - accuracy: 0.6954 - auc: 0.7278 - f1score: 0.7629 - loss: 0.5803 - precision: 0.7327 - recall: 0.7957 - val_accuracy: 0.7843 - val_auc: 0.7895 - val_f1score: 0.8136 - val_loss: 0.5826 - val_precision: 0.8571 - val_recall: 0.7742
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 648ms/step - accuracy: 0.6490 - auc: 0.6875 - f1score: 0.7440 - loss: 0.6060 - precision: 0.6754 - recall: 0.8280 - val_accuracy: 0.7255 - val_auc: 0.7823 - val_f1score: 0.7407 - val_loss: 0.5977 - val_precision: 0.8696 - val_recall: 0.6452
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.7020 - auc: 0.7778 - f1score: 0.7761 - loss: 0.5515 - precision: 0.7222 - recall: 0.8387 - val_accuracy: 0.6667 - val_auc: 0.7871 - val_f1score: 0.7536 - val_loss: 0.5795 - val_precision: 0.6842 - val_recall: 0.8387
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 672ms/step - accuracy: 0.6159 - auc: 0.6452 - f1score: 0.7010 - loss: 0.6362 - precision: 0.6733 - recall: 0.7312 - val_accuracy: 0.7843 - val_auc: 0.7887 - val_f1score: 0.8136 - val_loss: 0.5929 - val_precision: 0.8571 - val_recall: 0.7742
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 14s 758ms/step - accuracy: 0.6556 - auc: 0.7118 - f1score: 0.7679 - loss: 0.6218 - precision: 0.6565 - recall: 0.9247 - val_accuracy: 0.6667 - val_auc: 0.7677 - val_f1score: 0.6792 - val_loss: 0.6049 - val_precision: 0.8182 - val_recall: 0.5806
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 768ms/step - accuracy: 0.6556 - auc: 0.6787 - f1score: 0.7320 - loss: 0.6205 - precision: 0.7030 - recall: 0.7634 - val_accuracy: 0.6667 - val_auc: 0.7774 - val_f1score: 0.7733 - val_loss: 0.5859 - val_precision: 0.6591 - val_recall: 0.9355
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.6954 - auc: 0.7018 - f1score: 0.7767 - loss: 0.6008 - precision: 0.7080 - recall: 0.8602 - val_accuracy: 0.6471 - val_auc: 0.7944 - val_f1score: 0.6250 - val_loss: 0.6119 - val_precision: 0.8824 - val_recall: 0.4839
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 653ms/step - accuracy: 0.6623 - auc: 0.7061 - f1score: 0.7488 - loss: 0.6074 - precision: 0.6909 - recall: 0.8172 - val_accuracy: 0.6471 - val_auc: 0.7758 - val_f1score: 0.7568 - val_loss: 0.5930 - val_precision: 0.6512 - val_recall: 0.9032
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 652ms/step - accuracy: 0.6887 - auc: 0.7377 - f1score: 0.7729 - loss: 0.5759 - precision: 0.7018 - recall: 0.8602 - val_accuracy: 0.7647 - val_auc: 0.8032 - val_f1score: 0.7931 - val_loss: 0.5835 - val_precision: 0.8519 - val_recall: 0.7419

# %% [markdown]
# ## Training Curves

# %%
reportPath = os.path.join("reports", MODEL_TAG)
Path(reportPath).mkdir(parents=True, exist_ok=True)

skipEarlyEpochs = 3 # Remueve las primeras 3 epochs (aplastamiento visual de la grafica)

# Accuracy graph
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Train","Validation"])
plt.title("Accuracy")
plt.savefig(os.path.join(reportPath, "accuracy.png"), dpi=300, bbox_inches="tight")
plt.show()

# Loss graph
plt.figure(figsize=(10,4))
plt.plot(history.history["loss"][skipEarlyEpochs:])
plt.plot(history.history["val_loss"][skipEarlyEpochs:]) 
plt.legend(["Train","Validation"])
plt.title("Loss")
plt.savefig(os.path.join(reportPath, "loss.png"), dpi=300, bbox_inches="tight")
plt.show()

# New, recall graph, esta es la estadística que marco la mejora desde el modelo anterior
plt.figure(figsize=(10,4))
plt.plot(history.history["recall"])
plt.plot(history.history["val_recall"]) 
plt.legend(["Train","Validation"])
plt.title("Recall")
plt.savefig(os.path.join(reportPath, "recall.png"), dpi=300, bbox_inches="tight")
plt.show()

# New, f1score graph
plt.figure(figsize=(10,4))
plt.plot(history.history["f1score"])
plt.plot(history.history["val_f1score"]) 
plt.legend(["Train","Validation"])
plt.title("F1-Score")
plt.savefig(os.path.join(reportPath, "f1score.png"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Already saved based on f1score performance
